# %%
import pandas as pd
import numpy as np

# %%
from pathlib import Path

ROOT = Path.cwd().parent

df = pd.read_csv(ROOT / "dataset" / "weather.csv")

# %%
df.isnull().sum()
# Out:
# Date           0
# City           0
# Temperature    0
# Humidity       0
# Pressure       0
# Wind_Speed     0
# Cloud_Cover    0
# Rainfall       0
# Visibility     0
# Weather        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         5000 non-null   object
#  1   City         5000 non-null   object
#  2   Temperature  5000 non-null   float64
#  3   Humidity     5000 non-null   int64
#  4   Pressure     5000 non-null   int64
#  5   Wind_Speed   5000 non-null   float64
#  6   Cloud_Cover  5000 non-null   int64
#  7   Rainfall     5000 non-null   float64
#  8   Visibility   5000 non-null   int64
#  9   Weather      5000 non-null   object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 429.7+ KB

# %%
df.dtypes
# Out:
# Date            object
# City            object
# Temperature    float64
# Humidity         int64
# Pressure         int64
# Wind_Speed     float64
# Cloud_Cover      int64
# Rainfall       float64
# Visibility       int64
# Weather         object
# dtype: object

# %%
df["City"].unique()
# Out:
# array(['Chennai', 'Kolkata', 'Mysore', 'Mangalore', 'Goa', 'Pune',
#        'Hyderabad', 'Jaipur', 'Mumbai', 'Lucknow', 'Bhopal', 'Kochi',
#        'Ahmedabad', 'Delhi', 'Bangalore'], dtype=object)

# %%
df["Weather"].value_counts()
# Out:
# Clouds          748
# Thunderstorm    745
# Rain            742
# Mist            729
# Drizzle         725
# Haze            662
# Clear           649
# Name: Weather, dtype: int64

# %%
numeric_columns = ["Temperature", "Humidity", "Pressure",
                   "Wind_Speed", "Cloud_Cover",
                   "Rainfall", "Visibility"]

import matplotlib.pyplot as plt
import seaborn as sns

for col in numeric_columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col], color="skyblue")
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
df.to_csv(ROOT / "dataset" / "weather_clean.csv", index=False)
