# %%
import pandas as pd
import numpy as np

# %%
from pathlib import Path

ROOT = Path.cwd().parent

df = pd.read_csv(ROOT / "dataset" / "weather.csv")

# %%
df.isnull().sum()
# Out:
# Date           0
# City           0
# Temperature    0
# Humidity       0
# Pressure       0
# Wind_Speed     0
# Cloud_Cover    0
# Weather        0
# Rainfall       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         10000 non-null  str
#  1   City         10000 non-null  str
#  2   Temperature  10000 non-null  float64
#  3   Humidity     10000 non-null  int64
#  4   Pressure     10000 non-null  float64
#  5   Wind_Speed   10000 non-null  float64
#  6   Cloud_Cover  10000 non-null  int64
#  7   Weather      10000 non-null  str
#  8   Rainfall     10000 non-null  float64
# dtypes: float64(4), int64(2), str(3)
# memory usage: 1015.6 KB

# %%
df.dtypes
# Out:
# Date               str
# City               str
# Temperature    float64
# Humidity         int64
# Pressure       float64
# Wind_Speed     float64
# Cloud_Cover      int64
# Weather            str
# Rainfall       float64
# dtype: object

# %%
df["City"].unique()
# Out:
# <ArrowStringArray>
# [            'Mysuru',              'Anand',            'Bharuch',
#           'New_Delhi',          'Mangaluru',           'Amravati',
#             'Wayanad',          'Ahmedabad',            'Udaipur',
#          'Karimnagar',         'Kalaburagi',           'Warangal',
#             'Bikaner',             'Mumbai',               'Kota',
#          'Ganganagar',        'Delhi_North',            'Solapur',
#            'Kolhapur',          'Ratnagiri',             'Jaipur',
#               'Ajmer',         'Shivamogga',           'Thrissur',
#               'Kochi',           'Hubballi',          'Bengaluru',
#              'Kollam',             'Nashik',              'Surat',
#             'Khammam',             'Idukki',           'Junagadh',
#           'Hyderabad',            'Jodhpur',     'Chikkamagaluru',
#           'Kozhikode',         'Aurangabad',             'Nagpur',
#  'Thiruvananthapuram',             'Barmer',             'Rajkot',
#                'Pune',          'Bhavnagar',           'Adilabad',
#           'Nizamabad',            'Dharwad']
# Length: 47, dtype: str

# %%
df["Weather"].value_counts()
# Out:
# Weather
# Clear           5429
# Cloudy          2809
# Rain            1735
# Thunderstorm      27
# Name: count, dtype: int64

# %%
numeric_columns = ["Temperature", "Humidity", "Pressure",
                   "Wind_Speed", "Cloud_Cover",
                   "Rainfall"]

import matplotlib.pyplot as plt
import seaborn as sns

for col in numeric_columns:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col], color="skyblue")
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
if 'Visibility' in df.columns:
    df.drop('Visibility', axis=1, inplace=True)
df.to_csv(ROOT / 'dataset' / 'weather_clean.csv', index=False)
