# %%
import requests
import pandas as pd
from datetime import datetime

import warnings
warnings.filterwarnings("ignore")

# %%
API_KEY = "1becb0fb56249486d02f3d4f89203315"

CITY = "Mangalore"

# %%
url = (
    f"https://api.openweathermap.org/data/2.5/weather"
    f"?q={CITY}&appid={API_KEY}&units=metric"
)

# %%
response = requests.get(url)

print(response.status_code)

data = response.json()

data
# Out:
# 200
# {'coord': {'lon': 74.8833, 'lat': 12.8667},
#  'weather': [{'id': 501,
#    'main': 'Rain',
#    'description': 'moderate rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 25.93,
#   'feels_like': 26.85,
#   'temp_min': 25.93,
#   'temp_max': 25.93,
#   'pressure': 1011,
#   'humidity': 87,
#   'sea_level': 1011,
#   'grnd_level': 1007},
#  'visibility': 10000,
#  'wind': {'speed': 6.74, 'deg': 276, 'gust': 11.02},
#  'rain': {'1h': 1.77},
#  'clouds': {'all': 100},
#  'dt': 1786030271,
#  'sys': {'country': 'IN', 'sunrise': 1785977222, 'sunset': 1786022746},
#  'timezone': 19800,
#  'id': 1263780,
#  'name': 'Mangalore',
#  'cod': 200}

# %%
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=Mangalore&appid=1becb0fb56249486d02f3d4f89203315&units=metric

# %%
import requests

API_KEY = "1becb0fb56249486d02f3d4f89203315"

params = {
    "q": "Mangalore",
    "appid": API_KEY,
    "units": "metric"
}

response = requests.get(
    "https://api.openweathermap.org/data/2.5/weather",
    params=params
)

print(response.status_code)
print(response.text)
# Out:
# 200
# {"coord":{"lon":74.8833,"lat":12.8667},"weather":[{"id":501,"main":"Rain","description":"moderate rain","icon":"10n"}],"base":"stations","main":{"temp":25.93,"feels_like":26.85,"temp_min":25.93,"temp_max":25.93,"pressure":1011,"humidity":87,"sea_level":1011,"grnd_level":1007},"visibility":10000,"wind":{"speed":6.74,"deg":276,"gust":11.02},"rain":{"1h":1.77},"clouds":{"all":100},"dt":1786030271,"sys":{"country":"IN","sunrise":1785977222,"sunset":1786022746},"timezone":19800,"id":1263780,"name":"Mangalore","cod":200}

# %%
import requests

API_KEY = "1becb0fb56249486d02f3d4f89203315"

params = {
    "q": "Mangalore",
    "appid": API_KEY,
    "units": "metric"
}

response = requests.get(
    "https://api.openweathermap.org/data/2.5/weather",
    params=params
)

print("Status Code:", response.status_code)
print(response.json())
# Out:
# Status Code: 200
# {'coord': {'lon': 74.8833, 'lat': 12.8667}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 25.93, 'feels_like': 26.85, 'temp_min': 25.93, 'temp_max': 25.93, 'pressure': 1011, 'humidity': 87, 'sea_level': 1011, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 6.74, 'deg': 276, 'gust': 11.02}, 'rain': {'1h': 1.77}, 'clouds': {'all': 100}, 'dt': 1786030271, 'sys': {'country': 'IN', 'sunrise': 1785977222, 'sunset': 1786022746}, 'timezone': 19800, 'id': 1263780, 'name': 'Mangalore', 'cod': 200}

# %%
from pathlib import Path
import joblib

ROOT = Path.cwd().parent

le_city = joblib.load(ROOT / "models" / "le_city.pkl")
le_weather = joblib.load(ROOT / "models" / "le_weather.pkl")
le_day = joblib.load(ROOT / "models" / "le_day.pkl")
le_season = joblib.load(ROOT / "models" / "le_season.pkl")

print("✅ Encoders loaded successfully!")
# Out:
# ✅ Encoders loaded successfully!

# %%
print(le_city.classes_)
# Out:
# ['Adilabad' 'Ahmedabad' 'Ajmer' 'Amravati' 'Anand' 'Aurangabad' 'Barmer'
#  'Bengaluru' 'Bharuch' 'Bhavnagar' 'Bikaner' 'Chikkamagaluru'
#  'Delhi_North' 'Dharwad' 'Ganganagar' 'Hubballi' 'Hyderabad' 'Idukki'
#  'Jaipur' 'Jodhpur' 'Junagadh' 'Kalaburagi' 'Karimnagar' 'Khammam' 'Kochi'
#  'Kolhapur' 'Kollam' 'Kota' 'Kozhikode' 'Mangaluru' 'Mumbai' 'Mysuru'
#  'Nagpur' 'Nashik' 'New_Delhi' 'Nizamabad' 'Pune' 'Rajkot' 'Ratnagiri'
#  'Shivamogga' 'Solapur' 'Surat' 'Thiruvananthapuram' 'Thrissur' 'Udaipur'
#  'Warangal' 'Wayanad']

# %%
from pathlib import Path
import joblib

ROOT = Path.cwd().parent

le_weather = joblib.load(
    ROOT / "models" / "le_weather.pkl"
)

print(le_weather.classes_)
# Out:
# ['Clear' 'Cloudy' 'Rain' 'Thunderstorm']
