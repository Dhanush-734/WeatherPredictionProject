# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
from pathlib import Path

ROOT = Path.cwd().parent

df = pd.read_csv(ROOT / "dataset" / "weather_clean.csv")

# %%
df["Date"] = pd.to_datetime(
    df["Date"],
    format="%d-%m-%Y %H:%M"
)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         5000 non-null   datetime64[ns]
#  1   City         5000 non-null   object
#  2   Temperature  5000 non-null   float64
#  3   Humidity     5000 non-null   int64
#  4   Pressure     5000 non-null   int64
#  5   Wind_Speed   5000 non-null   float64
#  6   Cloud_Cover  5000 non-null   int64
#  7   Rainfall     5000 non-null   float64
#  8   Visibility   5000 non-null   int64
#  9   Weather      5000 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(4), object(2)
# memory usage: 390.8+ KB

# %%
print(df["City"].head())
print(df["City"].dtype)
print(df["City"].unique()[:10])
# Out:
# 0      Chennai
# 1      Kolkata
# 2       Mysore
# 3    Mangalore
# 4    Mangalore
# Name: City, dtype: object
# object
# ['Chennai' 'Kolkata' 'Mysore' 'Mangalore' 'Goa' 'Pune' 'Hyderabad'
#  'Jaipur' 'Mumbai' 'Lucknow']

# %%
df.head()
# Out:
#                  Date       City  Temperature  Humidity  Pressure  Wind_Speed  \
# 0 2024-01-01 00:00:00    Chennai         33.2        86      1000        10.7
# 1 2024-01-01 06:00:00    Kolkata         36.6        39      1003         5.8
# 2 2024-01-01 12:00:00     Mysore         16.3        83      1007         1.0
# 3 2024-01-01 18:00:00  Mangalore         31.5        80      1012         8.8
# 4 2024-01-02 00:00:00  Mangalore         18.1        36       995         0.7
#
#    Cloud_Cover  Rainfall  Visibility  Weather
# 0           72       1.4        5000     Rain
# 1           62       0.1        5000  Drizzle
# 2           10       1.7        7000     Rain
# 3           85       4.8        7000    Clear
# 4           56       0.0        5000   Clouds

# %%
df["Date"] = pd.to_datetime(
    df["Date"],
    format="%d-%m-%Y %H:%M"
)

# %%
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month
df["Day"] = df["Date"].dt.day
df["Hour"] = df["Date"].dt.hour
df["DayOfWeek"] = df["Date"].dt.day_name()

# %%
df.head()
# Out:
#                  Date       City  Temperature  Humidity  Pressure  Wind_Speed  \
# 0 2024-01-01 00:00:00    Chennai         33.2        86      1000        10.7
# 1 2024-01-01 06:00:00    Kolkata         36.6        39      1003         5.8
# 2 2024-01-01 12:00:00     Mysore         16.3        83      1007         1.0
# 3 2024-01-01 18:00:00  Mangalore         31.5        80      1012         8.8
# 4 2024-01-02 00:00:00  Mangalore         18.1        36       995         0.7
#
#    Cloud_Cover  Rainfall  Visibility  Weather  Year  Month  Day  Hour  \
# 0           72       1.4        5000     Rain  2024      1    1     0
# 1           62       0.1        5000  Drizzle  2024      1    1     6
# 2           10       1.7        7000     Rain  2024      1    1    12
# 3           85       4.8        7000    Clear  2024      1    1    18
# 4           56       0.0        5000   Clouds  2024      1    2     0
#
#   DayOfWeek
# 0    Monday
# 1    Monday
# 2    Monday
# 3    Monday
# 4   Tuesday

# %%
def get_season(month):
    if month in [12, 1, 2]:
        return "Winter"
    elif month in [3, 4, 5]:
        return "Summer"
    elif month in [6, 7, 8]:
        return "Monsoon"
    else:
        return "Post-Monsoon"

df["Season"] = df["Month"].apply(get_season)

# %%
df[["Month","Season"]].head(15)
# Out:
#     Month  Season
# 0       1  Winter
# 1       1  Winter
# 2       1  Winter
# 3       1  Winter
# 4       1  Winter
# 5       1  Winter
# 6       1  Winter
# 7       1  Winter
# 8       1  Winter
# 9       1  Winter
# 10      1  Winter
# 11      1  Winter
# 12      1  Winter
# 13      1  Winter
# 14      1  Winter

# %%
from sklearn.preprocessing import LabelEncoder
import joblib

# Create encoders
le_city = LabelEncoder()
le_weather = LabelEncoder()
le_day = LabelEncoder()
le_season = LabelEncoder()

# Fit on ORIGINAL text columns
le_city.fit(df["City"])
le_weather.fit(df["Weather"])
le_day.fit(df["DayOfWeek"])
le_season.fit(df["Season"])

# Save encoders BEFORE transforming
from pathlib import Path

ROOT = Path.cwd().parent

joblib.dump(le_city, ROOT / "models" / "le_city.pkl")
joblib.dump(le_weather, ROOT / "models" / "le_weather.pkl")
joblib.dump(le_day, ROOT / "models" / "le_day.pkl")
joblib.dump(le_season, ROOT / "models" / "le_season.pkl")

print("Encoders saved successfully!")
# Out:
# Encoders saved successfully!

# %%
from pathlib import Path
import joblib

ROOT = Path.cwd().parent

joblib.dump(le_city, ROOT / "models" / "le_city.pkl")
# Out:
# ['d:\\weather\\WeatherPredictionProject\\models\\le_city.pkl']

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.1

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\CANARA\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\canara\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\canara\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\canara\anaconda3\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\canara\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\canara\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.1

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\CANARA\anaconda3\python.exe

# %%
import sys
# !{sys.executable} -m pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\canara\anaconda3\lib\site-packages (1.2.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\canara\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\canara\anaconda3\lib\site-packages (from scikit-learn) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\canara\anaconda3\lib\site-packages (from scikit-learn) (1.10.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\canara\anaconda3\lib\site-packages (from scikit-learn) (1.23.5)

# %%
from sklearn.preprocessing import LabelEncoder

le_city = LabelEncoder()
le_weather = LabelEncoder()
le_day = LabelEncoder()
le_season = LabelEncoder()

df["City"] = le_city.fit_transform(df["City"])
df["Weather"] = le_weather.fit_transform(df["Weather"])
df["DayOfWeek"] = le_day.fit_transform(df["DayOfWeek"])
df["Season"] = le_season.fit_transform(df["Season"])

# %%
if "Date" in df.columns:
    df.drop("Date", axis=1, inplace=True)

# %%
df.head()
# Out:
#    City  Temperature  Humidity  Pressure  Wind_Speed  Cloud_Cover  Rainfall  \
# 0     3         33.2        86      1000        10.7           72       1.4
# 1     9         36.6        39      1003         5.8           62       0.1
# 2    13         16.3        83      1007         1.0           10       1.7
# 3    11         31.5        80      1012         8.8           85       4.8
# 4    11         18.1        36       995         0.7           56       0.0
#
#    Visibility  Weather  Year  Month  Day  Hour  DayOfWeek  Season
# 0        5000        5  2024      1    1     0          1       3
# 1        5000        2  2024      1    1     6          1       3
# 2        7000        5  2024      1    1    12          1       3
# 3        7000        0  2024      1    1    18          1       3
# 4        5000        1  2024      1    2     0          5       3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   City         5000 non-null   int32
#  1   Temperature  5000 non-null   float64
#  2   Humidity     5000 non-null   int64
#  3   Pressure     5000 non-null   int64
#  4   Wind_Speed   5000 non-null   float64
#  5   Cloud_Cover  5000 non-null   int64
#  6   Rainfall     5000 non-null   float64
#  7   Visibility   5000 non-null   int64
#  8   Weather      5000 non-null   int32
#  9   Year         5000 non-null   int64
#  10  Month        5000 non-null   int64
#  11  Day          5000 non-null   int64
#  12  Hour         5000 non-null   int64
#  13  DayOfWeek    5000 non-null   int32
#  14  Season       5000 non-null   int32
# dtypes: float64(3), int32(4), int64(8)
# memory usage: 507.9 KB

# %%
X = df.drop("Temperature", axis=1)

y = df["Temperature"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (5000, 14)
# (5000,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print("Training:", X_train.shape)
print("Testing :", X_test.shape)
# Out:
# Training: (4000, 14)
# Testing : (1000, 14)

# %%
df.to_csv(
    ROOT / "dataset" / "weather_featured.csv",
    index=False
)

# %%
print(X.columns.tolist())
# Out:
# ['City', 'Humidity', 'Pressure', 'Wind_Speed', 'Cloud_Cover', 'Rainfall', 'Visibility', 'Weather', 'Year', 'Month', 'Day', 'Hour', 'DayOfWeek', 'Season']

# %%
import joblib

joblib.dump(le_city, "../models/le_city.pkl")
joblib.dump(le_weather, "../models/le_weather.pkl")
joblib.dump(le_day, "../models/le_day.pkl")
joblib.dump(le_season, "../models/le_season.pkl")

print("Encoders saved successfully!")
# Out:
# Encoders saved successfully!
