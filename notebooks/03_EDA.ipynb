# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

plt.style.use("ggplot")

# %%
from pathlib import Path

ROOT = Path.cwd().parent

df = pd.read_csv(ROOT / "dataset" / "weather_clean.csv")

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 10000
# Columns : 9

# %%
df.describe()
# Out:
#         Temperature      Humidity      Pressure    Wind_Speed   Cloud_Cover  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      25.645750     63.994900    972.071420     35.927892     47.826900
# std        5.568755     24.130108     31.309043     19.328231     41.995013
# min        2.300000      4.000000    891.900000      0.000000      0.000000
# 25%       22.400000     45.000000    948.300000     22.320000      1.000000
# 50%       25.700000     68.000000    977.200000     32.040000     42.000000
# 75%       28.900000     85.000000   1000.700000     46.440000     97.000000
# max       44.100000    100.000000   1018.700000    132.480000    100.000000
#
#            Rainfall
# count  10000.000000
# mean       0.136400
# std        0.598546
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       23.200000

# %%
df.describe()
# Out:
#         Temperature      Humidity      Pressure    Wind_Speed   Cloud_Cover  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      25.645750     63.994900    972.071420     35.927892     47.826900
# std        5.568755     24.130108     31.309043     19.328231     41.995013
# min        2.300000      4.000000    891.900000      0.000000      0.000000
# 25%       22.400000     45.000000    948.300000     22.320000      1.000000
# 50%       25.700000     68.000000    977.200000     32.040000     42.000000
# 75%       28.900000     85.000000   1000.700000     46.440000     97.000000
# max       44.100000    100.000000   1018.700000    132.480000    100.000000
#
#            Rainfall
# count  10000.000000
# mean       0.136400
# std        0.598546
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max       23.200000

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Temperature"], bins=30, kde=True, color="red")

plt.title("Temperature Distribution")
plt.xlabel("Temperature")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Temperature"], bins=30, kde=True, color="red")

plt.title("Temperature Distribution")
plt.xlabel("Temperature")
plt.ylabel("Frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Pressure"], bins=30, kde=True, color="green")

plt.title("Pressure Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Pressure"], bins=30, kde=True, color="green")

plt.title("Pressure Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Wind_Speed"], bins=30, kde=True)

plt.title("Wind Speed Distribution")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(x="Weather", data=df)

plt.title("Weather Conditions")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(x="Weather", data=df)

plt.title("Weather Conditions")

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(x="City", data=df.head())

plt.title("City Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(x="Humidity",
                y="Temperature",
                data=df)

plt.title("Temperature vs Humidity")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(x="Pressure",
                y="Temperature",
                data=df)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(x="Cloud_Cover",
                y="Rainfall",
                data=df)

plt.show()

# %%
plt.figure(figsize=(10,6))

numeric_df = df.select_dtypes(include=["number"])

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
sns.pairplot(
    df[["Temperature",
        "Humidity",
        "Pressure",
        "Wind_Speed"]]
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x="City",
    y="Temperature",
    data=df.head()
)

plt.title("Average Temperature by City")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    x="City",
    y="Humidity",
    data=df.head()
)

plt.show()

# %%
plt.savefig("../output/graphs/temperature_distribution.png", dpi=300, bbox_inches="tight")
