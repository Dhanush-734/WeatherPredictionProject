# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
from pathlib import Path

ROOT = Path.cwd().parent

df = pd.read_csv(
    ROOT / "dataset" / "weather_featured.csv"
)

df.head()
# Out:
#    City  Temperature  Humidity  Pressure  Wind_Speed  Cloud_Cover  Rainfall  \
# 0     3         33.2        86      1000        10.7           72       1.4
# 1     9         36.6        39      1003         5.8           62       0.1
# 2    13         16.3        83      1007         1.0           10       1.7
# 3    11         31.5        80      1012         8.8           85       4.8
# 4    11         18.1        36       995         0.7           56       0.0
#
#    Visibility  Weather  Year  Month  Day  Hour  DayOfWeek  Season
# 0        5000        5  2024      1    1     0          1       3
# 1        5000        2  2024      1    1     6          1       3
# 2        7000        5  2024      1    1    12          1       3
# 3        7000        0  2024      1    1    18          1       3
# 4        5000        1  2024      1    2     0          5       3

# %%
X = df.drop("Temperature", axis=1)

y = df["Temperature"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

print("Training:", X_train.shape)
print("Testing :", X_test.shape)
# Out:
# Training: (4000, 14)
# Testing : (1000, 14)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train, y_train)

lr_pred = lr.predict(X_test)

# %%
from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor(random_state=42)

dt.fit(X_train, y_train)

dt_pred = dt.predict(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)

rf_pred = rf.predict(X_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb = GradientBoostingRegressor(random_state=42)

gb.fit(X_train, y_train)

gb_pred = gb.predict(X_test)

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import numpy as np

# %%
def evaluate_model(name, y_test, prediction):

    mae = mean_absolute_error(y_test, prediction)

    mse = mean_squared_error(y_test, prediction)

    rmse = np.sqrt(mse)

    r2 = r2_score(y_test, prediction)

    print("="*50)

    print(name)

    print("="*50)

    print("MAE :", round(mae,3))

    print("MSE :", round(mse,3))

    print("RMSE:", round(rmse,3))

    print("R2 :", round(r2,3))

# %%
evaluate_model("Linear Regression", y_test, lr_pred)

evaluate_model("Decision Tree", y_test, dt_pred)

evaluate_model("Random Forest", y_test, rf_pred)

evaluate_model("Gradient Boosting", y_test, gb_pred)
# Out:
# ==================================================
# Linear Regression
# ==================================================
# MAE : 5.431
# MSE : 39.669
# RMSE: 6.298
# R2 : -0.004
# ==================================================
# Decision Tree
# ==================================================
# MAE : 7.386
# MSE : 81.762
# RMSE: 9.042
# R2 : -1.07
# ==================================================
# Random Forest
# ==================================================
# MAE : 5.528
# MSE : 41.289
# RMSE: 6.426
# R2 : -0.045
# ==================================================
# Gradient Boosting
# ==================================================
# MAE : 5.5
# MSE : 40.878
# RMSE: 6.394
# R2 : -0.035

# %%
results = pd.DataFrame({

    "Model":[
        "Linear Regression",
        "Decision Tree",
        "Random Forest",
        "Gradient Boosting"
    ],

    "R2":[
        r2_score(y_test, lr_pred),
        r2_score(y_test, dt_pred),
        r2_score(y_test, rf_pred),
        r2_score(y_test, gb_pred)
    ]

})

results
# Out:
#                Model        R2
# 0  Linear Regression -0.004248
# 1      Decision Tree -1.069834
# 2      Random Forest -0.045247
# 3  Gradient Boosting -0.034854

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.bar(results["Model"], results["R2"])

plt.title("Model Comparison")

plt.ylabel("R2 Score")

plt.xticks(rotation=20)

plt.show()

# %%
results.sort_values(
    by="R2",
    ascending=False
)
# Out:
#                Model        R2
# 0  Linear Regression -0.004248
# 3  Gradient Boosting -0.034854
# 2      Random Forest -0.045247
# 1      Decision Tree -1.069834

# %%
from pathlib import Path
import joblib

ROOT = Path.cwd().parent

joblib.dump(
    rf,
    ROOT / "models" / "weather_model.pkl"
)

print("✅ Model saved successfully!")
# Out:
# ✅ Model saved successfully!

# %%
from pathlib import Path
import joblib

ROOT = Path.cwd().parent

model = joblib.load(
    ROOT / "models" / "weather_model.pkl"
)

print(model)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from pathlib import Path
import joblib

ROOT = Path.cwd().parent

joblib.dump(
    rf,
    ROOT / "models" / "weather_model.pkl"
)

print("✅ Model Saved Successfully!")
# Out:
# ✅ Model Saved Successfully!
