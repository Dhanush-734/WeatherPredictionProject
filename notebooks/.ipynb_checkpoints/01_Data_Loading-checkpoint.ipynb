# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
import os
print(os.getcwd())
# Out:
# d:\weather\WeatherPredictionProject\notebooks

# %%
from pathlib import Path

ROOT = Path.cwd().parent

df = pd.read_csv(ROOT / "dataset" / "weather.csv")
df.head()
# Out:
#                Date       City  Temperature  Humidity  Pressure  Wind_Speed  \
# 0  01-01-2024 00:00    Chennai         33.2        86      1000        10.7
# 1  01-01-2024 06:00    Kolkata         36.6        39      1003         5.8
# 2  01-01-2024 12:00     Mysore         16.3        83      1007         1.0
# 3  01-01-2024 18:00  Mangalore         31.5        80      1012         8.8
# 4  02-01-2024 00:00  Mangalore         18.1        36       995         0.7
#
#    Cloud_Cover  Rainfall  Visibility  Weather
# 0           72       1.4        5000     Rain
# 1           62       0.1        5000  Drizzle
# 2           10       1.7        7000     Rain
# 3           85       4.8        7000    Clear
# 4           56       0.0        5000   Clouds

# %%
df.head(10)
# Out:
#                Date       City  Temperature  Humidity  Pressure  Wind_Speed  \
# 0  01-01-2024 00:00    Chennai         33.2        86      1000        10.7
# 1  01-01-2024 06:00    Kolkata         36.6        39      1003         5.8
# 2  01-01-2024 12:00     Mysore         16.3        83      1007         1.0
# 3  01-01-2024 18:00  Mangalore         31.5        80      1012         8.8
# 4  02-01-2024 00:00  Mangalore         18.1        36       995         0.7
# 5  02-01-2024 06:00        Goa         19.9        81      1017         9.4
# 6  02-01-2024 12:00       Pune         24.0        84      1004         0.8
# 7  02-01-2024 18:00  Hyderabad         30.0        42       995        11.7
# 8  03-01-2024 00:00     Jaipur         35.2        66      1006         2.0
# 9  03-01-2024 06:00  Hyderabad         16.1        88      1005        11.4
#
#    Cloud_Cover  Rainfall  Visibility       Weather
# 0           72       1.4        5000          Rain
# 1           62       0.1        5000       Drizzle
# 2           10       1.7        7000          Rain
# 3           85       4.8        7000         Clear
# 4           56       0.0        5000        Clouds
# 5           23       0.0        6000         Clear
# 6           91       3.4        7000          Rain
# 7           62       0.0        6000        Clouds
# 8           31       0.0        8000          Mist
# 9           65       1.3        9000  Thunderstorm

# %%
df.tail(10)
# Out:
#                   Date       City  Temperature  Humidity  Pressure  \
# 4990  01-06-2027 12:00    Lucknow         27.3        36      1006
# 4991  01-06-2027 18:00     Jaipur         29.7        53      1003
# 4992  02-06-2027 00:00    Kolkata         18.4        70      1022
# 4993  02-06-2027 06:00    Chennai         30.5        51      1002
# 4994  02-06-2027 12:00  Ahmedabad         18.1        73      1001
# 4995  02-06-2027 18:00     Mumbai         26.1        77       997
# 4996  03-06-2027 00:00     Jaipur         18.0        79      1001
# 4997  03-06-2027 06:00  Mangalore         29.0        61      1015
# 4998  03-06-2027 12:00     Mumbai         22.4        42      1003
# 4999  03-06-2027 18:00      Kochi         27.6        83      1019
#
#       Wind_Speed  Cloud_Cover  Rainfall  Visibility       Weather
# 4990         6.2           22       0.0        9000          Haze
# 4991         3.1           81       2.0        6000        Clouds
# 4992         7.2           43       1.1        5000          Haze
# 4993         0.7           68       3.4        7000  Thunderstorm
# 4994         0.9           29       0.2        7000       Drizzle
# 4995         9.3           73       4.5        6000          Mist
# 4996         9.1           92       1.6       10000       Drizzle
# 4997         4.3           20       2.4        6000        Clouds
# 4998         1.4           74       2.4        6000       Drizzle
# 4999         1.5           23       0.0        8000          Rain

# %%
df.shape
# Out:
# (5000, 10)

# %%
df.columns
# Out:
# Index(['Date', 'City', 'Temperature', 'Humidity', 'Pressure', 'Wind_Speed',
#        'Cloud_Cover', 'Rainfall', 'Visibility', 'Weather'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         5000 non-null   object
#  1   City         5000 non-null   object
#  2   Temperature  5000 non-null   float64
#  3   Humidity     5000 non-null   int64
#  4   Pressure     5000 non-null   int64
#  5   Wind_Speed   5000 non-null   float64
#  6   Cloud_Cover  5000 non-null   int64
#  7   Rainfall     5000 non-null   float64
#  8   Visibility   5000 non-null   int64
#  9   Weather      5000 non-null   object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 390.8+ KB

# %%
df.describe()
# Out:
#        Temperature     Humidity     Pressure   Wind_Speed  Cloud_Cover  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean     27.053280    64.752000  1008.597200     6.342380    49.037800
# std       6.324734    17.785909     8.009456     3.334623    29.075857
# min      16.000000    35.000000   995.000000     0.500000     0.000000
# 25%      21.700000    49.000000  1002.000000     3.400000    24.000000
# 50%      27.100000    65.000000  1009.000000     6.500000    49.000000
# 75%      32.600000    80.000000  1015.000000     9.200000    74.000000
# max      38.000000    95.000000  1022.000000    12.000000   100.000000
#
#           Rainfall    Visibility
# count  5000.000000   5000.000000
# mean      1.334680   7514.200000
# std       1.541706   1704.223939
# min       0.000000   5000.000000
# 25%       0.000000   6000.000000
# 50%       0.800000   8000.000000
# 75%       2.300000   9000.000000
# max      10.900000  10000.000000

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(10)
# Out:
#                   Date       City  Temperature  Humidity  Pressure  \
# 953   26-08-2024 06:00     Bhopal         25.4        85       998
# 2457  06-09-2025 06:00  Bangalore         34.2        81      1018
# 2400  23-08-2025 00:00  Mangalore         37.6        82      1010
# 3881  28-08-2026 06:00  Bangalore         26.6        77      1006
# 4779  09-04-2027 18:00    Kolkata         24.0        94       997
# 984   03-09-2024 00:00  Ahmedabad         23.1        48      1019
# 748   06-07-2024 00:00     Bhopal         23.4        63      1000
# 2027  21-05-2025 18:00  Hyderabad         19.5        74      1003
# 2532  25-09-2025 00:00    Kolkata         28.1        80      1008
# 71    18-01-2024 18:00     Mysore         21.0        86      1012
#
#       Wind_Speed  Cloud_Cover  Rainfall  Visibility       Weather
# 953          8.7           36       0.0        5000        Clouds
# 2457        10.7           67       1.6        6000  Thunderstorm
# 2400        11.3           68       0.4        8000          Mist
# 3881         7.7           27       1.4        6000       Drizzle
# 4779         3.1           20       0.0        6000          Rain
# 984          6.8           87       3.3       10000          Rain
# 748          5.9            3       0.2        5000          Haze
# 2027         3.0            4       0.0        5000         Clear
# 2532         2.1           45       1.5        6000          Haze
# 71           7.0           40       2.7        9000          Rain

# %%
df.memory_usage(deep=True)
# Out:
# Index             128
# Date           365000
# City           317804
# Temperature     40000
# Humidity        40000
# Pressure        40000
# Wind_Speed      40000
# Cloud_Cover     40000
# Rainfall        40000
# Visibility      40000
# Weather        315280
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         5000 non-null   object
#  1   City         5000 non-null   object
#  2   Temperature  5000 non-null   float64
#  3   Humidity     5000 non-null   int64
#  4   Pressure     5000 non-null   int64
#  5   Wind_Speed   5000 non-null   float64
#  6   Cloud_Cover  5000 non-null   int64
#  7   Rainfall     5000 non-null   float64
#  8   Visibility   5000 non-null   int64
#  9   Weather      5000 non-null   object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 390.8+ KB
